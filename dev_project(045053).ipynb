# %% [markdown]
# importing data of men sneakers from AJIO.COM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('dark_background')

df = pd.read_csv('/content/drive/MyDrive/ajio.csv')
df.head()
# Out:
#                      rilrtl-products-list__link href brand  \
# 0  https://www.ajio.com/nike-downshifter-12-runni...  NIKE
# 1  https://www.ajio.com/nike-revolution-6-nn-runn...  NIKE
# 2  https://www.ajio.com/nike-revolution-6-flyease...  NIKE
# 3  https://www.ajio.com/nike-court-vision-lace-up...  NIKE
# 4  https://www.ajio.com/nike-revolution-6-nn-runn...  NIKE
#
#                               nameCls   price orginal-price   discount  \
# 0        Downshifter 12 Running Shoes  ₹2,797        ₹3,995  (30% off)
# 1       Revolution 6 NN Running Shoes  ₹2,919        ₹3,695  (21% off)
# 2  Revolution 6 Flyease Running Shoes  ₹2,587        ₹3,695  (30% off)
# 3       COURT VISION Lace-Up Sneakers  ₹4,496        ₹4,995  (10% off)
# 4       Revolution 6 NN Running Shoes  ₹2,513        ₹3,695  (32% off)
#
#    Unnamed: 6 offer price
# 0         NaN       2,597
# 1         NaN       2,771
# 2         NaN       2,508
# 3         NaN       4,417
# 4         NaN       2,402

# %% [markdown]
# 1. Display Top 10 Rows of The Dataset

# %%
df.head(10)
# Out:
#                      rilrtl-products-list__link href   brand  \
# 0  https://www.ajio.com/nike-downshifter-12-runni...    NIKE
# 1  https://www.ajio.com/nike-revolution-6-nn-runn...    NIKE
# 2  https://www.ajio.com/nike-revolution-6-flyease...    NIKE
# 3  https://www.ajio.com/nike-court-vision-lace-up...    NIKE
# 4  https://www.ajio.com/nike-revolution-6-nn-runn...    NIKE
# 5  https://www.ajio.com/7-10-round-neck-stacked-s...  07-Oct
# 6  https://www.ajio.com/nike-downshifter-12-runni...    NIKE
# 7  https://www.ajio.com/nike-air-max-ap-running-s...    NIKE
# 8  https://www.ajio.com/nike-downshifter-12-runni...    NIKE
# 9  https://www.ajio.com/nike-venture-runner-casua...    NIKE
#
#                               nameCls   price orginal-price   discount  \
# 0        Downshifter 12 Running Shoes  ₹2,797        ₹3,995  (30% off)
# 1       Revolution 6 NN Running Shoes  ₹2,919        ₹3,695  (21% off)
# 2  Revolution 6 Flyease Running Shoes  ₹2,587        ₹3,695  (30% off)
# ...

# %% [markdown]
# 2. Check Last 10 Rows of The Dataset

# %%
df.tail(10)
# Out:
#                         rilrtl-products-list__link href         brand  \
# 2518  https://www.ajio.com/puma-rapido-ii-tt-jr-lace...          Puma
# 2519  https://www.ajio.com/toms-carlo-blue-casual-sh...          Toms
# 2520  https://www.ajio.com/puma-softride-vital-walki...          Puma
# 2521  https://www.ajio.com/steve-madden-striped-driv...  STEVE MADDEN
# 2522  https://www.ajio.com/steve-madden-collapsable-...  STEVE MADDEN
# 2523  https://www.ajio.com/puma-puma-drive-fusion-di...          Puma
# 2524  https://www.ajio.com/veja-esplar-lace-up-sneak...          Veja
# 2525  https://www.ajio.com/puma-mapf1-a3rocat-lace-u...          Puma
# 2526  https://www.ajio.com/skechers-go-run-400-v2--o...      Skechers
# 2527  https://www.ajio.com/puma-nrgy-comet-preschool...          Puma
#
#                                            nameCls    price orginal-price  \
# 2518          Rapido II TT Jr Lace-Up Sports Shoes   ₹2,249        ₹2,499
# ...

# %% [markdown]
# 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
df.shape

()

print("Number of Rows:",df.shape[0])
print("Number of Columns:",df.shape[1])
# Out:
# Number of Rows: 2528
# Number of Columns: 8

# %% [markdown]
# 4.changing datatype of offer price column from object to int

# %%
df['offer price'].astype(int)
# Out:
# Series([], Name: offer price, dtype: int64)

# %% [markdown]
# 5. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2528 entries, 0 to 2527
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   rilrtl-products-list__link href  2528 non-null   object
#  1   brand                            2528 non-null   object
#  2   nameCls                          2528 non-null   object
#  3   price                            2528 non-null   object
#  4   orginal-price                    2363 non-null   object
#  5   discount                         2363 non-null   object
#  6   Unnamed: 6                       0 non-null      float64
#  7   offer price                      2491 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 158.1+ KB

# %% [markdown]
# 6.datatype of each column

# %%
df.dtypes
# Out:
# rilrtl-products-list__link href     object
# brand                               object
# nameCls                             object
# price                               object
# orginal-price                       object
# discount                            object
# Unnamed: 6                         float64
# offer price                         object
# dtype: object

# %% [markdown]
# 7. Check Missing Values In The Dataset

# %%
print("Is there any missing value?",df.isnull().values.any())
# Out:
# Is there any missing value? True

# %%
df.isnull().sum()
# Out:
# rilrtl-products-list__link href       0
# brand                                 0
# nameCls                               0
# price                                 0
# orginal-price                       165
# discount                            165
# Unnamed: 6                         2528
# offer price                          37
# dtype: int64

# %%
df.isnull().sum().astype(float)
# Out:
# rilrtl-products-list__link href       0.0
# brand                                 0.0
# nameCls                               0.0
# price                                 0.0
# orginal-price                       165.0
# discount                            165.0
# Unnamed: 6                         2528.0
# offer price                          37.0
# dtype: float64

# %% [markdown]
# 8.how many shoes are of NIKE. Similarly we could find about other brands.

# %%
df.columns
# Out:
# Index(['rilrtl-products-list__link href', 'brand', 'nameCls', 'price',
#        'orginal-price', 'discount', 'Unnamed: 6', 'offer price'],
#       dtype='object')

# %%
df['brand'].astype(str)
len(df[df['brand']=="NIKE"])
df[df['brand']=="NIKE"].count()
# Out:
# rilrtl-products-list__link href    196
# brand                              196
# nameCls                            196
# price                              196
# orginal-price                      194
# discount                           194
# Unnamed: 6                           0
# offer price                        196
# dtype: int64

# %% [markdown]
# 9. Check For Duplicate Data

# %%
df.duplicated().sum()
# Out:
# 330

# %%
print("Are there any duplicate values?",df.duplicated().values.any())

df
# Out:
# Are there any duplicate values? True
#                         rilrtl-products-list__link href     brand  \
# 0     https://www.ajio.com/nike-downshifter-12-runni...      NIKE
# 1     https://www.ajio.com/nike-revolution-6-nn-runn...      NIKE
# 2     https://www.ajio.com/nike-revolution-6-flyease...      NIKE
# 3     https://www.ajio.com/nike-court-vision-lace-up...      NIKE
# 4     https://www.ajio.com/nike-revolution-6-nn-runn...      NIKE
# ...                                                 ...       ...
# 2523  https://www.ajio.com/puma-puma-drive-fusion-di...      Puma
# 2524  https://www.ajio.com/veja-esplar-lace-up-sneak...      Veja
# 2525  https://www.ajio.com/puma-mapf1-a3rocat-lace-u...      Puma
# 2526  https://www.ajio.com/skechers-go-run-400-v2--o...  Skechers
# 2527  https://www.ajio.com/puma-nrgy-comet-preschool...      Puma
#
#                                           nameCls    price orginal-price  \
# ...

# %% [markdown]
# 10.dropping duplicate

# %%
df.drop_duplicates(inplace = True)
df.shape
# Out:
# (2198, 8)

# %% [markdown]
# 11. Drop All The Missing Values

# %%
df.dropna(inplace=True)

df
# Out:
# Empty DataFrame
# Columns: [rilrtl-products-list__link href, brand, nameCls, price, orginal-price, discount, Unnamed: 6, offer price]
# Index: []

# %% [markdown]
# 12.maximum and minimum offer price

# %%
df.columns
# Out:
# Index(['rilrtl-products-list__link href', 'brand', 'nameCls', 'price',
#        'orginal-price', 'discount', 'Unnamed: 6', 'offer price'],
#       dtype='object')

# %%
df['offer price'].astype(int)
df['offer price'].max()

# %% [markdown]
# 13. Get Overall Statistics About The DataFrame

# %%
df.describe(include="all")
# Out:
#        rilrtl-products-list__link href brand nameCls price orginal-price  \
# count                                0     0       0     0             0
# unique                               0     0       0     0             0
# top                                NaN   NaN     NaN   NaN           NaN
# freq                               NaN   NaN     NaN   NaN           NaN
# mean                               NaN   NaN     NaN   NaN           NaN
# std                                NaN   NaN     NaN   NaN           NaN
# min                                NaN   NaN     NaN   NaN           NaN
# 25%                                NaN   NaN     NaN   NaN           NaN
# 50%                                NaN   NaN     NaN   NaN           NaN
# 75%                                NaN   NaN     NaN   NaN           NaN
# max                                NaN   NaN     NaN   NaN           NaN
#
#        discount  Unnamed: 6 offer price
# count         0         0.0           0
# ...

# %% [markdown]
# 14. Display brand of The sneakers having price >=5000

# %%
df.columns
# Out:
# Index(['rilrtl-products-list__link href', 'brand', 'nameCls', 'price',
#        'orginal-price', 'discount', 'Unnamed: 6', 'offer price'],
#       dtype='object')

# %%
df['offer price'].astype(int)
df[df["offer price"]>=5000]["brand"]
# Out:
# Series([], Name: brand, dtype: object)

# %% [markdown]
# 15. Display Top 10 costliest sneaker

# %%
df.columns
# Out:
# Index(['rilrtl-products-list__link href', 'brand', 'nameCls', 'price',
#        'orginal-price', 'discount', 'Unnamed: 6', 'offer price'],
#       dtype='object')

# %%
df['offer price'].astype(int)

top_10=df.sort_values(by='offer price', ascending=False).head(10)

top_10=top_10[['brand','offer price']].set_index('brand')

top_10
# Out:
# Empty DataFrame
# Columns: [offer price]
# Index: []

# %% [markdown]
# 16.Rename column

# %%
df.rename(columns= {'brand':'company'})
# Out:
# Empty DataFrame
# Columns: [rilrtl-products-list__link href, company, nameCls, price, orginal-price, discount, Unnamed: 6, offer price]
# Index: []

# %% [markdown]
# 17. describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)

# %%
df.describe()
# Out:
#        Unnamed: 6
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %% [markdown]
# **Exploratory Data Analysis**

# %% [markdown]
# 18. Cleaning discount Column

# %%
discount = df['discount'].value_counts(ascending  = False)
discount
# Out:
# Series([], Name: discount, dtype: int64)

# %%
#Histogram Discount
# Set the bin edges for the histogram
bins = [0, 10, 20, 30, 40, 50, 60,70]

# Createion of histogram
plt.figure(figsize=(10, 6))
plt.hist(df["discount"], bins=bins, edgecolor='k', alpha=0.7)

# Customising
plt.title("Distribution of Discounts")
plt.xlabel("discount")
plt.ylabel("Frequency")
plt.xticks(bins)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Saving as an image file
plt.savefig("discount_histogram.png")

plt.show()

#sneakers with the highest and lowest discounts.


# Sorting the DataFrame by "discount" in descending order to find the highest discounts
highest_discounts = df.sort_values(by="discount", ascending=False)

# Sorting the DataFrame by "discount" in ascending order to find the lowest discounts
lowest_discounts = df.sort_values(by="discount", ascending=True)

# sneakers with the highest and lowest discounts
highest_discount = highest_discounts.iloc[0]
lowest_discount= lowest_discounts.iloc[0]

print("sneakers with the highest discount:")
print(highest_discount)

print("sneakers with the lowest discount:")
print(lowest_discount)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-86a40b3afe2a> in <cell line: 31>()
#      29
#      30 # sneakers with the highest and lowest discounts
# ---> 31 highest_discount = highest_discounts.iloc[0]
#      32 lowest_discount= lowest_discounts.iloc[0]
#      33
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1623
#    1624             # validate the location
# -> 1625             self._validate_integer(key, axis)
#    1626
#    1627             return self.obj._ixs(key, axis=axis)
# ...

# %%
#Plot price against discount percentage to visualize how discounts affect prices.
# Scatter plot of Price vs. Discount Percentage
plt.figure(figsize=(10, 6))
plt.scatter(df["discount"], df[" price"], alpha=0.5)
plt.xlabel("Discount Percentage")
plt.ylabel("Price (in INR)")
plt.title("Price vs. Discount Percentage")
plt.grid(True)

# Save the plot
plt.savefig("price_vs_discount.png")

plt.show()

# %%
df.columns

offer_price=df.groupby('offer price')['discount'].mean()
offer_price

ax=offer_price.plot(kind='bar')
plt.ylabel('discount')
plt.title('Votes By Year')
plt.show()
